# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Shree Com\\Desktop\\Data\\ecommerce_data.csv")

# %%
df
# Out:
#               date  product_id  city_id  orders
# 0       2019-12-16        1897       26       2
# 1       2019-12-16        4850       26       4
# 2       2019-12-16        2466       26       1
# 3       2019-12-16         637       26       1
# 4       2019-12-16        3497       26     184
# ...            ...         ...      ...     ...
# 523679  2019-01-02        3064        8       2
# 523680  2019-01-04        3064        8       1
# 523681  2019-01-08        3064        8       3
# 523682  2019-01-09        3064        8       1
# 523683  2019-01-10        3064        8       6
#
# [523684 rows x 4 columns]

# %%
df
# Out:
#               date  product_id  city_id  orders
# 0       2019-12-16        1897       26       2
# 1       2019-12-16        4850       26       4
# 2       2019-12-16        2466       26       1
# 3       2019-12-16         637       26       1
# 4       2019-12-16        3497       26     184
# ...            ...         ...      ...     ...
# 523679  2019-01-02        3064        8       2
# 523680  2019-01-04        3064        8       1
# 523681  2019-01-08        3064        8       3
# 523682  2019-01-09        3064        8       1
# 523683  2019-01-10        3064        8       6
#
# [523684 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  object
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 16.0+ MB

# %%
df["date"]=pd.to_datetime(df["date"])

# %%
df
# Out:
#              date  product_id  city_id  orders
# 0      2019-12-16        1897       26       2
# 1      2019-12-16        4850       26       4
# 2      2019-12-16        2466       26       1
# 3      2019-12-16         637       26       1
# 4      2019-12-16        3497       26     184
# ...           ...         ...      ...     ...
# 523679 2019-01-02        3064        8       2
# 523680 2019-01-04        3064        8       1
# 523681 2019-01-08        3064        8       3
# 523682 2019-01-09        3064        8       1
# 523683 2019-01-10        3064        8       6
#
# [523684 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  datetime64[ns]
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 16.0 MB

# %% [markdown]
# # extract year

# %%
df["year"]=df["date"].dt.year

# %%
df.head(5)
# Out:
#         date  product_id  city_id  orders  year
# 0 2019-12-16        1897       26       2  2019
# 1 2019-12-16        4850       26       4  2019
# 2 2019-12-16        2466       26       1  2019
# 3 2019-12-16         637       26       1  2019
# 4 2019-12-16        3497       26     184  2019

# %% [markdown]
# # month

# %%
df["month"]=df["date"].dt.month

# %%
df.head(5)
# Out:
#         date  product_id  city_id  orders  year  month
# 0 2019-12-16        1897       26       2  2019     12
# 1 2019-12-16        4850       26       4  2019     12
# 2 2019-12-16        2466       26       1  2019     12
# 3 2019-12-16         637       26       1  2019     12
# 4 2019-12-16        3497       26     184  2019     12

# %%
df["month_name"]=df["date"].dt.month_name()

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name
# 355103 2019-07-19        7215       16       8  2019      7       July
# 106425 2018-08-21        7028       26      31  2018      8     August
# 155910 2018-08-11        2860       28      17  2018      8     August
# 516465 2018-10-10        4846        1       4  2018     10    October
# 104433 2018-08-10        3245       26      15  2018      8     August

# %% [markdown]
# # day

# %%
df["day"]=df["date"].dt.day

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day
# 269732 2019-11-05        6151       25      26  2019     11   November    5
# 82349  2019-12-04        4347       25     132  2019     12   December    4
# 108820 2018-08-29        1571        2       4  2018      8     August   29
# 62346  2019-05-19         911       17       1  2019      5        May   19
# 156337 2018-09-13        2310       29       1  2018      9  September   13

# %%
df["day_name"]=df["date"].dt.day_name()

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 436640 2018-12-21         687       14       2  2018     12   December   21
# 80921  2019-11-29        4367        0       1  2019     11   November   29
# 32352  2019-10-17         617       27       2  2019     10    October   17
# 63942  2019-04-30        5361       28       9  2019      4      April   30
# 308855 2019-08-10        6475       13      26  2019      8     August   10
#
#         day_name
# 436640    Friday
# 80921     Friday
# 32352   Thursday
# 63942    Tuesday
# 308855  Saturday

# %% [markdown]
# # day of week

# %%
df["day_of_week"]=df["date"].dt.day_of_week

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 197811 2019-03-20        2459        0       1  2019      3      March   20
# 464382 2018-12-26        7212        4       3  2018     12   December   26
# 213839 2019-03-25        6163       16       3  2019      3      March   25
# 438025 2018-10-25        5458       14      13  2018     10    October   25
# 504627 2018-09-29        5061        3      26  2018      9  September   29
#
#          day_name  day_of_week
# 197811  Wednesday            2
# 464382  Wednesday            2
# 213839     Monday            0
# 438025   Thursday            3
# 504627   Saturday            5

# %% [markdown]
# # extract extract weekend

# %%
df["week_end"]=np.where(df["day_name"].isin(["Sunday","Saturday"]),1,0)

# %%
df
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 0      2019-12-16        1897       26       2  2019     12   December   16
# 1      2019-12-16        4850       26       4  2019     12   December   16
# 2      2019-12-16        2466       26       1  2019     12   December   16
# 3      2019-12-16         637       26       1  2019     12   December   16
# 4      2019-12-16        3497       26     184  2019     12   December   16
# ...           ...         ...      ...     ...   ...    ...        ...  ...
# 523679 2019-01-02        3064        8       2  2019      1    January    2
# 523680 2019-01-04        3064        8       1  2019      1    January    4
# 523681 2019-01-08        3064        8       3  2019      1    January    8
# 523682 2019-01-09        3064        8       1  2019      1    January    9
# 523683 2019-01-10        3064        8       6  2019      1    January   10
#
#          day_name  day_of_week  week_end
# ...

# %% [markdown]
# # extract week of year

# %%
df["week_of_year"]=df["date"].dt.week
# Out:
# C:\Users\Shree Com\AppData\Local\Temp\ipykernel_10132\2151333272.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week_of_year"]=df["date"].dt.week

# %%
df.sample(4)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 34577  2019-10-13         374       17       2  2019     10    October   13
# 65055  2019-05-01        5448        1      13  2019      5        May    1
# 269846 2019-10-28        1348       10      29  2019     10    October   28
# 520350 2018-10-03        5649       10       1  2018     10    October    3
#
#          day_name  day_of_week  week_end  week_of_year
# 34577      Sunday            6         1            41
# 65055   Wednesday            2         0            18
# 269846     Monday            0         0            44
# 520350  Wednesday            2         0            40

# %% [markdown]
# #  extract quarter

# %%
df["quarter"]=df["date"].dt.quarter

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 435847 2018-11-02         343       14       2  2018     11   November    2
# 135580 2018-08-03        6603        5       6  2018      8     August    3
# 56009  2019-05-07        6343       22     318  2019      5        May    7
# 517697 2019-01-03        2002        1       4  2019      1    January    3
# 250374 2019-04-03        1014       10       2  2019      4      April    3
#
#          day_name  day_of_week  week_end  week_of_year  quarter
# 435847     Friday            4         0            44        4
# 135580     Friday            4         0            31        3
# 56009     Tuesday            1         0            19        2
# 517697   Thursday            3         0             1        1
# 250374  Wednesday            2         0            14        2

# %% [markdown]
# # how to extract time elapse between  dates

# %%
import datetime

# %%
today=datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2023, 5, 11, 14, 7, 5, 11086)

# %%
today-df["date"]
# Out:
# 0        1242 days 14:07:05.011086
# 1        1242 days 14:07:05.011086
# 2        1242 days 14:07:05.011086
# 3        1242 days 14:07:05.011086
# 4        1242 days 14:07:05.011086
#                     ...
# 523679   1590 days 14:07:05.011086
# 523680   1588 days 14:07:05.011086
# 523681   1584 days 14:07:05.011086
# 523682   1583 days 14:07:05.011086
# 523683   1582 days 14:07:05.011086
# Name: date, Length: 523684, dtype: timedelta64[ns]

# %%
(today-df["date"]).dt.days
# Out:
# 0         1242
# 1         1242
# 2         1242
# 3         1242
# 4         1242
#           ...
# 523679    1590
# 523680    1588
# 523681    1584
# 523682    1583
# 523683    1582
# Name: date, Length: 523684, dtype: int64

# %% [markdown]
# # extract hour

# %%
df["hour"]=df["date"].dt.hour

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 100234 2019-11-29         479       19       2  2019     11   November   29
# 67123  2019-11-28        4850       26       6  2019     11   November   28
# 294440 2019-07-14        7028       26      24  2019      7       July   14
# 406470 2018-10-03        3119       26      69  2018     10    October    3
# 58406  2019-06-01        1725       18       1  2019      6       June    1
#
#          day_name  day_of_week  week_end  week_of_year  quarter  hour
# 100234     Friday            4         0            48        4     0
# 67123    Thursday            3         0            48        4     0
# 294440     Sunday            6         1            28        3     0
# 406470  Wednesday            2         0            40        4     0
# 58406    Saturday            5         1            22        2     0

# %% [markdown]
# # extract minute

# %%
df["minute"]=df["date"].dt.minute

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 119937 2018-07-25        4391       14      63  2018      7       July   25
# 374162 2019-07-24        1932       18       5  2019      7       July   24
# 309679 2019-06-06         573       13       4  2019      6       June    6
# 500938 2018-10-11        6807        6       9  2018     10    October   11
# 313014 2019-07-18        5407       13     108  2019      7       July   18
#
#          day_name  day_of_week  week_end  week_of_year  quarter  hour  minute
# 119937  Wednesday            2         0            30        3     0       0
# 374162  Wednesday            2         0            30        3     0       0
# 309679   Thursday            3         0            23        2     0       0
# 500938   Thursday            3         0            41        4     0       0
# 313014   Thursday            3         0            29        3     0       0

# %% [markdown]
# # extract secound

# %%
df["second"]=df["date"].dt.second

# %%
df.sample(5)
# Out:
#              date  product_id  city_id  orders  year  month month_name  day  \
# 394533 2019-07-17         267       28       2  2019      7       July   17
# 404580 2018-12-17        6159       26       2  2018     12   December   17
# 355095 2019-07-19        4374       16       1  2019      7       July   19
# 43094  2019-05-26        2610       13       1  2019      5        May   26
# 110789 2018-08-21        6427       13       1  2018      8     August   21
#
#          day_name  day_of_week  week_end  week_of_year  quarter  hour  minute  \
# 394533  Wednesday            2         0            29        3     0       0
# 404580     Monday            0         0            51        4     0       0
# 355095     Friday            4         0            29        3     0       0
# 43094      Sunday            6         1            21        2     0       0
# 110789    Tuesday            1         0            34        3     0       0
#
#         second
# 394533       0
# ...
